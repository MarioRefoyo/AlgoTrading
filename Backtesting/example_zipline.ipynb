# %%
# %reload_ext zipline

# %%
from zipline.api import order_target, record, symbol, set_benchmark

def initialize(context):
    context.i = 0
    context.asset = symbol('AAPL')
    set_benchmark(False)


def handle_data(context, data):
    # Skip first 300 days to get full windows
    context.i += 1
    if context.i < 300:
        return

    # Compute averages
    # data.history() has to be called with the same params
    # from above and returns a pandas dataframe.
    short_mavg = data.history(context.asset, 'price', bar_count=100, frequency="1d").mean()
    long_mavg = data.history(context.asset, 'price', bar_count=300, frequency="1d").mean()

    # Trading logic
    if short_mavg > long_mavg:
        # order_target orders as many shares as needed to
        # achieve the desired number of shares.
        order_target(context.asset, 100)
    elif short_mavg < long_mavg:
        order_target(context.asset, 0)

    # Save values for later inspection
    record(AAPL=data.current(context.asset, 'price'),
           short_mavg=short_mavg,
           long_mavg=long_mavg)

# %%
% zipline --bundle quantopian-quandl --start 2008-1-1 --end 2012-1-1 -o strat.pickle
# Out:
# C:\Users\Mario\anaconda3\envs\backtestingg\lib\site-packages\empyrical\stats.py:711: RuntimeWarning: invalid value encountered in true_divide
#   out=out,
# C:\Users\Mario\anaconda3\envs\backtestingg\lib\site-packages\empyrical\stats.py:797: RuntimeWarning: invalid value encountered in true_divide
#   np.divide(average_annual_return, annualized_downside_risk, out=out)
#                               AAPL  algo_volatility  algorithm_period_return  \
# 2008-01-02 21:00:00+00:00      NaN              NaN                 0.000000
# 2008-01-03 21:00:00+00:00      NaN         0.000000                 0.000000
# 2008-01-04 21:00:00+00:00      NaN         0.000000                 0.000000
# 2008-01-07 21:00:00+00:00      NaN         0.000000                 0.000000
# 2008-01-08 21:00:00+00:00      NaN         0.000000                 0.000000
# 2008-01-09 21:00:00+00:00      NaN         0.000000                 0.000000
# ...

# %%
# !pip install alpaca-trade-api
# Out:
# ...
#   Using cached alpaca_trade_api-0.49.1-py3-none-any.whl (38 kB)
# ERROR: Could not find a version that satisfies the requirement websockets<9,>=8.0 (from alpaca-trade-api) (from versions: 1.0, 2.0, 2.1, 2.2, 2.3, 2.4, 2.5, 2.6, 2.7, 3.0, 3.1, 3.2, 3.3, 3.4, 4.0, 4.0.1, 5.0, 5.0.1, 6.0, 7.0)
# ERROR: No matching distribution found for websockets<9,>=8.0 (from alpaca-trade-api)

# %%
! zipline run --bundle quantopian-quandl -f dual_moving_average.py --start 2000-1-1 --end 2018-1-1 --output buyapple_out.pickle
# Out:
# [2020-08-15 00:51:15.871696] WARNING: zipline.utils.run_algo: No benchmark configured. Assuming algorithm calls set_benchmark.
# [2020-08-15 00:51:15.872699] WARNING: zipline.utils.run_algo: Pass --benchmark-sid, --benchmark-symbol, or --benchmark-file to set a source of benchmark returns.
# [2020-08-15 00:51:15.872699] WARNING: zipline.utils.run_algo: Pass --no-benchmark to use a dummy benchmark of zero returns.
# Error: Neither '--benchmark-symbol' nor '--benchmark-sid' was provided, and ``zipline.api.set_benchmark`` was not called in ``initialize``. Did you mean to pass '--no-benchmark'?
